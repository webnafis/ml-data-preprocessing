# %% [markdown]
# <a href="https://colab.research.google.com/github/webnafis/ml-data-preprocessing/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Preprocessing Tools**

# %% [markdown]
# # Importing the libraries
